# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 5
sample_id = 8
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 5:
# Samples: 10000
# Label Counts: {0: 1014, 1: 1014, 2: 952, 3: 1016, 4: 997, 5: 1025, 6: 980, 7: 977, 8: 1003, 9: 1022}
# First 20 Labels: [1, 8, 5, 1, 5, 7, 4, 3, 8, 2, 7, 2, 0, 1, 5, 9, 6, 2, 0, 8]
#
# Example of Image 8:
# Image - Min Value: 0 Max Value: 247
# Image - Shape: (32, 32, 3)
# Label - Label Id: 8 Name: ship

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x, a=0.0, b=1.0):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    x_min = np.amin(x)
    x_max = np.amax(x)
    X = a + (((x - x_min) * (b-a)) / (x_max - x_min))
    return X

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
# Create the one-hot encoding map for 10 unique label values
encodings = {}
unique_labels = 10
for i in range(unique_labels):
    encoding = np.zeros(unique_labels) # create an empty zero array
    encoding[i] = 1.0 # one-hot encode
    encodings[i] = encoding # set the encoding value lookup
    
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    global encodings        
    return np.array( [ encodings[l] for l in x ] )


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    return tf.placeholder(tf.float32, shape=(None, *image_shape), name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    return tf.placeholder(tf.float32, shape=(None, n_classes), name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    return tf.placeholder(tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # Create weight variables
    weight = tf.Variable(
        tf.truncated_normal(
            shape=[int(conv_ksize[0]), int(conv_ksize[1]), int(x_tensor.shape[3]), conv_num_outputs]
        )
    )
    # Create bias variable
    bias = tf.Variable(
        tf.zeros(conv_num_outputs)
    )
    # Create convolution layer
    conv_layer = tf.nn.conv2d(
        x_tensor,
        weight,
        strides=(1, *conv_strides, 1),
        padding='SAME'
    )
    # Add bias
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    # Add non-linear activation
    conv_layer = tf.nn.relu(conv_layer)
    # Apply Max Pooling
    conv_layer = tf.nn.max_pool(
        conv_layer,
        (1, *pool_ksize, 1),
        (1, *pool_strides, 1),
        padding='SAME'
    )
    return conv_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    flattened_size = int(x_tensor.shape[1]) * int(x_tensor.shape[2]) * int(x_tensor.shape[3])
    result = tf.reshape(
        x_tensor,
        shape=(-1, flattened_size)
    )
    return result


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # Create weight variables
    weight = tf.Variable(
        tf.truncated_normal(
            shape=(int(x_tensor.shape[1]), num_outputs),
            stddev=0.1
        )
    )
    # Create bias variable
    bias = tf.Variable(
        #tf.constant(0.1, shape=(num_outputs,))
        tf.zeros(num_outputs)
    )
    # Apply the weights
    fc = tf.add(
        tf.matmul(x_tensor, weight),
        bias
    )
    # Activations
    fc = tf.nn.relu(fc)
    # Return result
    return fc


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # Create weight variable
    weight = tf.Variable(
        tf.truncated_normal(
            shape=(int(x_tensor.shape[1]), num_outputs),
            stddev=0.1
        )
    )
    # Create bias variable
    bias = tf.Variable(
        #tf.constant(0.1, shape=(num_outputs,))
        tf.zeros(num_outputs)
    )
    # Apply the weights
    ol = tf.add(
        tf.matmul(x_tensor, weight),
        bias
    )
    return ol


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
from collections import namedtuple

cn_layer_param = namedtuple(
    'Param',
    ['conv_num_output', 'conv_ksize', 'conv_strides', 'pool_ksize', 'pool_strides']
)

def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # Define the CNN layer parameters
    # Layer 1 : 32x32x3  -> 8x8x32
    cn_layers = (
        (32, (5,5), (2,2), (2,2), (2,2)),
    )
    
    # Apply 1, 2, or 3 Convolution and Max Pool layers
    ly = x
    for cn_layer in cn_layers:
        ly = conv2d_maxpool(
            ly,
            *cn_layer
        )

    # Apply a Flatten Layer
    ly = flatten(ly)
    
    # Apply 1, 2, or 3 Fully Connected Layers
    fc_layers = (
        128,
        "dropout",
        20,
    )
    for fc_layer in fc_layers:
        if fc_layer == "dropout":
            ly = tf.nn.dropout(
                ly,
                keep_prob
            )
        else:
            ly = fully_conn(
                ly,
                fc_layer
            )
    
    # Output layer
    ly = output(
        ly,
        len(encodings) # number of classes
    )
    
    return ly


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    global x, y, keep_prob
    session.run(
        optimizer,
        feed_dict={
            x: feature_batch,
            y: label_batch,
            keep_prob: keep_probability
        }
    )

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    global x, y, keep_prob
    global valid_features, valid_labels
    current_cost, current_accuracy = session.run(
        (cost, accuracy),
        feed_dict={
            x: feature_batch,
            y: label_batch,
            keep_prob: 1.0
        }
    )
    
    valid_cost, valid_accuracy = session.run(
        (cost, accuracy),
        feed_dict={
            x: valid_features,
            y: valid_labels,
            keep_prob: 1.0
        }
    )
    
    print('\nTraining -   Cost: {:<8.3} Accuracy: {:<5.3}'.format(current_cost, current_accuracy))
    print('Validation - Cost: {:<8.3} Accuracy: {:<5.3}'.format(valid_cost, valid_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# Tune Parameters
epochs = 50
batch_size = 256
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:
# Training -   Cost: 2.22     Accuracy: 0.2
# Validation - Cost: 2.22     Accuracy: 0.145
# Epoch  2, CIFAR-10 Batch 1:
# Training -   Cost: 2.16     Accuracy: 0.125
# Validation - Cost: 2.15     Accuracy: 0.18
# Epoch  3, CIFAR-10 Batch 1:
# Training -   Cost: 2.09     Accuracy: 0.4
# Validation - Cost: 2.07     Accuracy: 0.25
# Epoch  4, CIFAR-10 Batch 1:
# Training -   Cost: 2.0      Accuracy: 0.275
# Validation - Cost: 1.93     Accuracy: 0.308
# Epoch  5, CIFAR-10 Batch 1:
# Training -   Cost: 1.85     Accuracy: 0.4
# Validation - Cost: 1.8      Accuracy: 0.354
# Epoch  6, CIFAR-10 Batch 1:
# Training -   Cost: 1.79     Accuracy: 0.45
# Validation - Cost: 1.73     Accuracy: 0.366
# Epoch  7, CIFAR-10 Batch 1:
# Training -   Cost: 1.66     Accuracy: 0.45
# Validation - Cost: 1.69     Accuracy: 0.382
# Epoch  8, CIFAR-10 Batch 1:
# Training -   Cost: 1.59     Accuracy: 0.45
# Validation - Cost: 1.65     Accuracy: 0.395
# Epoch  9, CIFAR-10 Batch 1:
# Training -   Cost: 1.53     Accuracy: 0.425
# Validation - Cost: 1.64     Accuracy: 0.398
# Epoch 10, CIFAR-10 Batch 1:
# Training -   Cost: 1.47     Accuracy: 0.425
# Validation - Cost: 1.61     Accuracy: 0.41
# Epoch 11, CIFAR-10 Batch 1:
# Training -   Cost: 1.38     Accuracy: 0.45
# Validation - Cost: 1.58     Accuracy: 0.422
# Epoch 12, CIFAR-10 Batch 1:
# Training -   Cost: 1.31     Accuracy: 0.55
# Validation - Cost: 1.57     Accuracy: 0.425
# Epoch 13, CIFAR-10 Batch 1:
# Training -   Cost: 1.26     Accuracy: 0.525
# Validation - Cost: 1.54     Accuracy: 0.435
# Epoch 14, CIFAR-10 Batch 1:
# Training -   Cost: 1.2      Accuracy: 0.6
# Validation - Cost: 1.53     Accuracy: 0.449
# Epoch 15, CIFAR-10 Batch 1:
# Training -   Cost: 1.15     Accuracy: 0.65
# Validation - Cost: 1.5      Accuracy: 0.46
# Epoch 16, CIFAR-10 Batch 1:
# Training -   Cost: 1.12     Accuracy: 0.625
# Validation - Cost: 1.51     Accuracy: 0.45
# Epoch 17, CIFAR-10 Batch 1:
# Training -   Cost: 1.02     Accuracy: 0.7
# Validation - Cost: 1.5      Accuracy: 0.46
# Epoch 18, CIFAR-10 Batch 1:
# Training -   Cost: 1.02     Accuracy: 0.65
# Validation - Cost: 1.47     Accuracy: 0.47
# Epoch 19, CIFAR-10 Batch 1:
# Training -   Cost: 0.991    Accuracy: 0.65
# Validation - Cost: 1.46     Accuracy: 0.47
# Epoch 20, CIFAR-10 Batch 1:
# Training -   Cost: 0.987    Accuracy: 0.675
# Validation - Cost: 1.46     Accuracy: 0.475
# Epoch 21, CIFAR-10 Batch 1:
# Training -   Cost: 0.903    Accuracy: 0.65
# Validation - Cost: 1.46     Accuracy: 0.478
# Epoch 22, CIFAR-10 Batch 1:
# Training -   Cost: 0.88     Accuracy: 0.7
# Validation - Cost: 1.43     Accuracy: 0.481
# Epoch 23, CIFAR-10 Batch 1:
# Training -   Cost: 0.868    Accuracy: 0.7
# Validation - Cost: 1.42     Accuracy: 0.491
# Epoch 24, CIFAR-10 Batch 1:
# Training -   Cost: 0.782    Accuracy: 0.725
# Validation - Cost: 1.4      Accuracy: 0.496
# Epoch 25, CIFAR-10 Batch 1:
# Training -   Cost: 0.794    Accuracy: 0.675
# Validation - Cost: 1.41     Accuracy: 0.494
# Epoch 26, CIFAR-10 Batch 1:
# Training -   Cost: 0.746    Accuracy: 0.8
# Validation - Cost: 1.4      Accuracy: 0.501
# Epoch 27, CIFAR-10 Batch 1:
# Training -   Cost: 0.722    Accuracy: 0.825
# Validation - Cost: 1.38     Accuracy: 0.505
# Epoch 28, CIFAR-10 Batch 1:
# Training -   Cost: 0.645    Accuracy: 0.8
# Validation - Cost: 1.39     Accuracy: 0.498
# Epoch 29, CIFAR-10 Batch 1:
# Training -   Cost: 0.626    Accuracy: 0.75
# Validation - Cost: 1.37     Accuracy: 0.507
# Epoch 30, CIFAR-10 Batch 1:
# Training -   Cost: 0.578    Accuracy: 0.825
# Validation - Cost: 1.38     Accuracy: 0.507
# Epoch 31, CIFAR-10 Batch 1:
# Training -   Cost: 0.593    Accuracy: 0.825
# Validation - Cost: 1.36     Accuracy: 0.513
# Epoch 32, CIFAR-10 Batch 1:
# Training -   Cost: 0.576    Accuracy: 0.825
# Validation - Cost: 1.37     Accuracy: 0.517
# Epoch 33, CIFAR-10 Batch 1:
# Training -   Cost: 0.547    Accuracy: 0.825
# Validation - Cost: 1.37     Accuracy: 0.511
# Epoch 34, CIFAR-10 Batch 1:
# Training -   Cost: 0.53     Accuracy: 0.85
# Validation - Cost: 1.37     Accuracy: 0.506
# Epoch 35, CIFAR-10 Batch 1:
# Training -   Cost: 0.502    Accuracy: 0.85
# Validation - Cost: 1.4      Accuracy: 0.511
# Epoch 36, CIFAR-10 Batch 1:
# Training -   Cost: 0.496    Accuracy: 0.85
# Validation - Cost: 1.36     Accuracy: 0.516
# Epoch 37, CIFAR-10 Batch 1:
# Training -   Cost: 0.482    Accuracy: 0.8
# Validation - Cost: 1.35     Accuracy: 0.523
# Epoch 38, CIFAR-10 Batch 1:
# Training -   Cost: 0.441    Accuracy: 0.85
# Validation - Cost: 1.37     Accuracy: 0.522
# Epoch 39, CIFAR-10 Batch 1:
# Training -   Cost: 0.443    Accuracy: 0.9
# Validation - Cost: 1.37     Accuracy: 0.516
# Epoch 40, CIFAR-10 Batch 1:
# Training -   Cost: 0.373    Accuracy: 0.925
# Validation - Cost: 1.35     Accuracy: 0.525
# Epoch 41, CIFAR-10 Batch 1:
# Training -   Cost: 0.385    Accuracy: 0.925
# Validation - Cost: 1.38     Accuracy: 0.52
# Epoch 42, CIFAR-10 Batch 1:
# Training -   Cost: 0.355    Accuracy: 0.9
# Validation - Cost: 1.38     Accuracy: 0.526
# Epoch 43, CIFAR-10 Batch 1:
# Training -   Cost: 0.345    Accuracy: 0.9
# Validation - Cost: 1.36     Accuracy: 0.531
# Epoch 44, CIFAR-10 Batch 1:
# Training -   Cost: 0.336    Accuracy: 0.95
# Validation - Cost: 1.35     Accuracy: 0.53
# Epoch 45, CIFAR-10 Batch 1:
# Training -   Cost: 0.348    Accuracy: 0.925
# Validation - Cost: 1.38     Accuracy: 0.522
# Epoch 46, CIFAR-10 Batch 1:
# Training -   Cost: 0.315    Accuracy: 0.95
# Validation - Cost: 1.38     Accuracy: 0.529
# Epoch 47, CIFAR-10 Batch 1:
# Training -   Cost: 0.309    Accuracy: 0.925
# Validation - Cost: 1.37     Accuracy: 0.528
# Epoch 48, CIFAR-10 Batch 1:
# Training -   Cost: 0.278    Accuracy: 0.95
# Validation - Cost: 1.37     Accuracy: 0.535
# Epoch 49, CIFAR-10 Batch 1:
# Training -   Cost: 0.272    Accuracy: 0.95
# Validation - Cost: 1.38     Accuracy: 0.526
# Epoch 50, CIFAR-10 Batch 1:
# Training -   Cost: 0.255    Accuracy: 0.975
# Validation - Cost: 1.38     Accuracy: 0.53

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:
# Training -   Cost: 2.3      Accuracy: 0.125
# Validation - Cost: 2.3      Accuracy: 0.0998
# Epoch  1, CIFAR-10 Batch 2:
# Training -   Cost: 2.23     Accuracy: 0.175
# Validation - Cost: 2.28     Accuracy: 0.128
# Epoch  1, CIFAR-10 Batch 3:
# Training -   Cost: 2.06     Accuracy: 0.225
# Validation - Cost: 2.12     Accuracy: 0.215
# Epoch  1, CIFAR-10 Batch 4:
# Training -   Cost: 2.01     Accuracy: 0.225
# Validation - Cost: 2.02     Accuracy: 0.237
# Epoch  1, CIFAR-10 Batch 5:
# Training -   Cost: 1.93     Accuracy: 0.375
# Validation - Cost: 1.92     Accuracy: 0.282
# Epoch  2, CIFAR-10 Batch 1:
# Training -   Cost: 2.1      Accuracy: 0.275
# Validation - Cost: 1.87     Accuracy: 0.303
# Epoch  2, CIFAR-10 Batch 2:
# Training -   Cost: 1.92     Accuracy: 0.275
# Validation - Cost: 1.82     Accuracy: 0.331
# Epoch  2, CIFAR-10 Batch 3:
# Training -   Cost: 1.68     Accuracy: 0.275
# Validation - Cost: 1.78     Accuracy: 0.351
# Epoch  2, CIFAR-10 Batch 4:
# Training -   Cost: 1.73     Accuracy: 0.375
# Validation - Cost: 1.77     Accuracy: 0.357
# Epoch  2, CIFAR-10 Batch 5:
# Training -   Cost: 1.73     Accuracy: 0.375
# Validation - Cost: 1.72     Accuracy: 0.367
# Epoch  3, CIFAR-10 Batch 1:
# Training -   Cost: 1.99     Accuracy: 0.35
# Validation - Cost: 1.71     Accuracy: 0.38
# Epoch  3, CIFAR-10 Batch 2:
# Training -   Cost: 1.68     Accuracy: 0.475
# Validation - Cost: 1.66     Accuracy: 0.399
# Epoch  3, CIFAR-10 Batch 3:
# Training -   Cost: 1.56     Accuracy: 0.475
# Validation - Cost: 1.65     Accuracy: 0.405
# Epoch  3, CIFAR-10 Batch 4:
# Training -   Cost: 1.65     Accuracy: 0.35
# Validation - Cost: 1.64     Accuracy: 0.417
# Epoch  3, CIFAR-10 Batch 5:
# Training -   Cost: 1.6      Accuracy: 0.45
# Validation - Cost: 1.6      Accuracy: 0.422
# Epoch  4, CIFAR-10 Batch 1:
# Training -   Cost: 1.9      Accuracy: 0.4
# Validation - Cost: 1.58     Accuracy: 0.42
# Epoch  4, CIFAR-10 Batch 2:
# Training -   Cost: 1.57     Accuracy: 0.5
# Validation - Cost: 1.56     Accuracy: 0.439
# Epoch  4, CIFAR-10 Batch 3:
# Training -   Cost: 1.41     Accuracy: 0.55
# Validation - Cost: 1.56     Accuracy: 0.438
# Epoch  4, CIFAR-10 Batch 4:
# Training -   Cost: 1.52     Accuracy: 0.45
# Validation - Cost: 1.53     Accuracy: 0.444
# Epoch  4, CIFAR-10 Batch 5:
# Training -   Cost: 1.53     Accuracy: 0.525
# Validation - Cost: 1.53     Accuracy: 0.444
# Epoch  5, CIFAR-10 Batch 1:
# Training -   Cost: 1.79     Accuracy: 0.45
# Validation - Cost: 1.52     Accuracy: 0.451
# Epoch  5, CIFAR-10 Batch 2:
# Training -   Cost: 1.44     Accuracy: 0.575
# Validation - Cost: 1.5      Accuracy: 0.457
# Epoch  5, CIFAR-10 Batch 3:
# Training -   Cost: 1.32     Accuracy: 0.575
# Validation - Cost: 1.51     Accuracy: 0.452
# Epoch  5, CIFAR-10 Batch 4:
# Training -   Cost: 1.44     Accuracy: 0.5
# Validation - Cost: 1.47     Accuracy: 0.475
# Epoch  5, CIFAR-10 Batch 5:
# Training -   Cost: 1.42     Accuracy: 0.5
# Validation - Cost: 1.45     Accuracy: 0.466
# Epoch  6, CIFAR-10 Batch 1:
# Training -   Cost: 1.65     Accuracy: 0.475
# Validation - Cost: 1.44     Accuracy: 0.474
# Epoch  6, CIFAR-10 Batch 2:
# Training -   Cost: 1.36     Accuracy: 0.575
# Validation - Cost: 1.42     Accuracy: 0.489
# Epoch  6, CIFAR-10 Batch 3:
# Training -   Cost: 1.25     Accuracy: 0.65
# Validation - Cost: 1.45     Accuracy: 0.482
# Epoch  6, CIFAR-10 Batch 4:
# Training -   Cost: 1.36     Accuracy: 0.475
# Validation - Cost: 1.41     Accuracy: 0.497
# Epoch  6, CIFAR-10 Batch 5:
# Training -   Cost: 1.35     Accuracy: 0.575
# Validation - Cost: 1.4      Accuracy: 0.491
# Epoch  7, CIFAR-10 Batch 1:
# Training -   Cost: 1.57     Accuracy: 0.525
# Validation - Cost: 1.39     Accuracy: 0.498
# Epoch  7, CIFAR-10 Batch 2:
# Training -   Cost: 1.25     Accuracy: 0.6
# Validation - Cost: 1.38     Accuracy: 0.507
# Epoch  7, CIFAR-10 Batch 3:
# Training -   Cost: 1.13     Accuracy: 0.65
# Validation - Cost: 1.4      Accuracy: 0.5
# Epoch  7, CIFAR-10 Batch 4:
# Training -   Cost: 1.29     Accuracy: 0.525
# Validation - Cost: 1.35     Accuracy: 0.515
# Epoch  7, CIFAR-10 Batch 5:
# Training -   Cost: 1.23     Accuracy: 0.65
# Validation - Cost: 1.34     Accuracy: 0.516
# Epoch  8, CIFAR-10 Batch 1:
# Training -   Cost: 1.43     Accuracy: 0.55
# Validation - Cost: 1.35     Accuracy: 0.521
# Epoch  8, CIFAR-10 Batch 2:
# Training -   Cost: 1.09     Accuracy: 0.6
# Validation - Cost: 1.37     Accuracy: 0.514
# Epoch  8, CIFAR-10 Batch 3:
# Training -   Cost: 1.07     Accuracy: 0.65
# Validation - Cost: 1.34     Accuracy: 0.523
# Epoch  8, CIFAR-10 Batch 4:
# Training -   Cost: 1.26     Accuracy: 0.525
# Validation - Cost: 1.33     Accuracy: 0.532
# Epoch  8, CIFAR-10 Batch 5:
# Training -   Cost: 1.19     Accuracy: 0.675
# Validation - Cost: 1.32     Accuracy: 0.525
# Epoch  9, CIFAR-10 Batch 1:
# Training -   Cost: 1.25     Accuracy: 0.6
# Validation - Cost: 1.31     Accuracy: 0.535
# Epoch  9, CIFAR-10 Batch 2:
# Training -   Cost: 1.02     Accuracy: 0.625
# Validation - Cost: 1.34     Accuracy: 0.529
# Epoch  9, CIFAR-10 Batch 3:
# Training -   Cost: 0.931    Accuracy: 0.725
# Validation - Cost: 1.32     Accuracy: 0.532
# Epoch  9, CIFAR-10 Batch 4:
# Training -   Cost: 1.17     Accuracy: 0.575
# Validation - Cost: 1.3      Accuracy: 0.533
# Epoch  9, CIFAR-10 Batch 5:
# Training -   Cost: 1.06     Accuracy: 0.725
# Validation - Cost: 1.28     Accuracy: 0.544
# Epoch 10, CIFAR-10 Batch 1:
# Training -   Cost: 1.2      Accuracy: 0.6
# Validation - Cost: 1.3      Accuracy: 0.541
# Epoch 10, CIFAR-10 Batch 2:
# Training -   Cost: 0.926    Accuracy: 0.725
# Validation - Cost: 1.31     Accuracy: 0.535
# Epoch 10, CIFAR-10 Batch 3:
# Training -   Cost: 0.925    Accuracy: 0.75
# Validation - Cost: 1.28     Accuracy: 0.546
# Epoch 10, CIFAR-10 Batch 4:
# Training -   Cost: 1.13     Accuracy: 0.65
# Validation - Cost: 1.26     Accuracy: 0.552
# Epoch 10, CIFAR-10 Batch 5:
# Training -   Cost: 0.998    Accuracy: 0.8
# Validation - Cost: 1.25     Accuracy: 0.556
# Epoch 11, CIFAR-10 Batch 1:
# Training -   Cost: 1.13     Accuracy: 0.675
# Validation - Cost: 1.26     Accuracy: 0.55
# Epoch 11, CIFAR-10 Batch 2:
# Training -   Cost: 0.855    Accuracy: 0.7
# Validation - Cost: 1.29     Accuracy: 0.547
# Epoch 11, CIFAR-10 Batch 3:
# Training -   Cost: 0.821    Accuracy: 0.7
# Validation - Cost: 1.25     Accuracy: 0.548
# Epoch 11, CIFAR-10 Batch 4:
# Training -   Cost: 1.04     Accuracy: 0.6
# Validation - Cost: 1.24     Accuracy: 0.56
# Epoch 11, CIFAR-10 Batch 5:
# Training -   Cost: 0.95     Accuracy: 0.725
# Validation - Cost: 1.24     Accuracy: 0.56
# Epoch 12, CIFAR-10 Batch 1:
# Training -   Cost: 1.04     Accuracy: 0.675
# Validation - Cost: 1.24     Accuracy: 0.566
# Epoch 12, CIFAR-10 Batch 2:
# Training -   Cost: 0.768    Accuracy: 0.8
# Validation - Cost: 1.26     Accuracy: 0.558
# Epoch 12, CIFAR-10 Batch 3:
# Training -   Cost: 0.803    Accuracy: 0.725
# Validation - Cost: 1.25     Accuracy: 0.553
# Epoch 12, CIFAR-10 Batch 4:
# Training -   Cost: 0.989    Accuracy: 0.6
# Validation - Cost: 1.22     Accuracy: 0.566
# Epoch 12, CIFAR-10 Batch 5:
# Training -   Cost: 0.889    Accuracy: 0.775
# Validation - Cost: 1.22     Accuracy: 0.564
# Epoch 13, CIFAR-10 Batch 1:
# Training -   Cost: 0.992    Accuracy: 0.675
# Validation - Cost: 1.22     Accuracy: 0.57
# Epoch 13, CIFAR-10 Batch 2:
# Training -   Cost: 0.716    Accuracy: 0.85
# Validation - Cost: 1.27     Accuracy: 0.558
# Epoch 13, CIFAR-10 Batch 3:
# Training -   Cost: 0.738    Accuracy: 0.8
# Validation - Cost: 1.22     Accuracy: 0.569
# Epoch 13, CIFAR-10 Batch 4:
# Training -   Cost: 0.885    Accuracy: 0.675
# Validation - Cost: 1.21     Accuracy: 0.568
# Epoch 13, CIFAR-10 Batch 5:
# Training -   Cost: 0.843    Accuracy: 0.775
# Validation - Cost: 1.2      Accuracy: 0.574
# Epoch 14, CIFAR-10 Batch 1:
# Training -   Cost: 0.957    Accuracy: 0.7
# Validation - Cost: 1.21     Accuracy: 0.572
# Epoch 14, CIFAR-10 Batch 2:
# Training -   Cost: 0.666    Accuracy: 0.825
# Validation - Cost: 1.24     Accuracy: 0.566
# Epoch 14, CIFAR-10 Batch 3:
# Training -   Cost: 0.722    Accuracy: 0.8
# Validation - Cost: 1.2      Accuracy: 0.576
# Epoch 14, CIFAR-10 Batch 4:
# Training -   Cost: 0.839    Accuracy: 0.65
# Validation - Cost: 1.2      Accuracy: 0.576
# Epoch 14, CIFAR-10 Batch 5:
# Training -   Cost: 0.794    Accuracy: 0.775
# Validation - Cost: 1.19     Accuracy: 0.584
# Epoch 15, CIFAR-10 Batch 1:
# Training -   Cost: 0.938    Accuracy: 0.75
# Validation - Cost: 1.18     Accuracy: 0.586
# Epoch 15, CIFAR-10 Batch 2:
# Training -   Cost: 0.658    Accuracy: 0.825
# Validation - Cost: 1.2      Accuracy: 0.581
# Epoch 15, CIFAR-10 Batch 3:
# Training -   Cost: 0.676    Accuracy: 0.8
# Validation - Cost: 1.2      Accuracy: 0.578
# Epoch 15, CIFAR-10 Batch 4:
# Training -   Cost: 0.776    Accuracy: 0.8
# Validation - Cost: 1.18     Accuracy: 0.59
# Epoch 15, CIFAR-10 Batch 5:
# Training -   Cost: 0.765    Accuracy: 0.8
# Validation - Cost: 1.17     Accuracy: 0.588
# Epoch 16, CIFAR-10 Batch 1:
# Training -   Cost: 0.906    Accuracy: 0.7
# Validation - Cost: 1.18     Accuracy: 0.586
# Epoch 16, CIFAR-10 Batch 2:
# Training -   Cost: 0.622    Accuracy: 0.875
# Validation - Cost: 1.21     Accuracy: 0.578
# Epoch 16, CIFAR-10 Batch 3:
# Training -   Cost: 0.612    Accuracy: 0.85
# Validation - Cost: 1.17     Accuracy: 0.595
# Epoch 16, CIFAR-10 Batch 4:
# Training -   Cost: 0.746    Accuracy: 0.8
# Validation - Cost: 1.17     Accuracy: 0.589
# Epoch 16, CIFAR-10 Batch 5:
# Training -   Cost: 0.722    Accuracy: 0.825
# Validation - Cost: 1.18     Accuracy: 0.593
# Epoch 17, CIFAR-10 Batch 1:
# Training -   Cost: 0.865    Accuracy: 0.7
# Validation - Cost: 1.17     Accuracy: 0.593
# Epoch 17, CIFAR-10 Batch 2:
# Training -   Cost: 0.572    Accuracy: 0.825
# Validation - Cost: 1.23     Accuracy: 0.576
# Epoch 17, CIFAR-10 Batch 3:
# Training -   Cost: 0.606    Accuracy: 0.85
# Validation - Cost: 1.17     Accuracy: 0.588
# Epoch 17, CIFAR-10 Batch 4:
# Training -   Cost: 0.683    Accuracy: 0.825
# Validation - Cost: 1.15     Accuracy: 0.601
# Epoch 17, CIFAR-10 Batch 5:
# Training -   Cost: 0.665    Accuracy: 0.875
# Validation - Cost: 1.15     Accuracy: 0.603
# Epoch 18, CIFAR-10 Batch 1:
# Training -   Cost: 0.836    Accuracy: 0.75
# Validation - Cost: 1.15     Accuracy: 0.601
# Epoch 18, CIFAR-10 Batch 2:
# Training -   Cost: 0.511    Accuracy: 0.9
# Validation - Cost: 1.21     Accuracy: 0.583
# Epoch 18, CIFAR-10 Batch 3:
# Training -   Cost: 0.628    Accuracy: 0.825
# Validation - Cost: 1.17     Accuracy: 0.588
# Epoch 18, CIFAR-10 Batch 4:
# Training -   Cost: 0.625    Accuracy: 0.8
# Validation - Cost: 1.14     Accuracy: 0.61
# Epoch 18, CIFAR-10 Batch 5:
# Training -   Cost: 0.607    Accuracy: 0.875
# Validation - Cost: 1.15     Accuracy: 0.596
# Epoch 19, CIFAR-10 Batch 1:
# Training -   Cost: 0.8      Accuracy: 0.725
# Validation - Cost: 1.14     Accuracy: 0.604
# Epoch 19, CIFAR-10 Batch 2:
# Training -   Cost: 0.482    Accuracy: 0.9
# Validation - Cost: 1.21     Accuracy: 0.581
# Epoch 19, CIFAR-10 Batch 3:
# Training -   Cost: 0.551    Accuracy: 0.925
# Validation - Cost: 1.15     Accuracy: 0.602
# Epoch 19, CIFAR-10 Batch 4:
# Training -   Cost: 0.57     Accuracy: 0.85
# Validation - Cost: 1.14     Accuracy: 0.603
# Epoch 19, CIFAR-10 Batch 5:
# Training -   Cost: 0.579    Accuracy: 0.9
# Validation - Cost: 1.13     Accuracy: 0.604
# Epoch 20, CIFAR-10 Batch 1:
# Training -   Cost: 0.777    Accuracy: 0.75
# Validation - Cost: 1.15     Accuracy: 0.594
# Epoch 20, CIFAR-10 Batch 2:
# Training -   Cost: 0.497    Accuracy: 0.925
# Validation - Cost: 1.17     Accuracy: 0.593
# Epoch 20, CIFAR-10 Batch 3:
# Training -   Cost: 0.568    Accuracy: 0.875
# Validation - Cost: 1.13     Accuracy: 0.608
# Epoch 20, CIFAR-10 Batch 4:
# Training -   Cost: 0.557    Accuracy: 0.8
# Validation - Cost: 1.14     Accuracy: 0.605
# Epoch 20, CIFAR-10 Batch 5:
# Training -   Cost: 0.557    Accuracy: 0.9
# Validation - Cost: 1.13     Accuracy: 0.608
# Epoch 21, CIFAR-10 Batch 1:
# Training -   Cost: 0.721    Accuracy: 0.8
# Validation - Cost: 1.13     Accuracy: 0.605
# Epoch 21, CIFAR-10 Batch 2:
# Training -   Cost: 0.45     Accuracy: 0.925
# Validation - Cost: 1.16     Accuracy: 0.591
# Epoch 21, CIFAR-10 Batch 3:
# Training -   Cost: 0.529    Accuracy: 0.95
# Validation - Cost: 1.13     Accuracy: 0.608
# Epoch 21, CIFAR-10 Batch 4:
# Training -   Cost: 0.51     Accuracy: 0.85
# Validation - Cost: 1.12     Accuracy: 0.617
# Epoch 21, CIFAR-10 Batch 5:
# Training -   Cost: 0.535    Accuracy: 0.875
# Validation - Cost: 1.12     Accuracy: 0.609
# Epoch 22, CIFAR-10 Batch 1:
# Training -   Cost: 0.695    Accuracy: 0.775
# Validation - Cost: 1.12     Accuracy: 0.615
# Epoch 22, CIFAR-10 Batch 2:
# Training -   Cost: 0.469    Accuracy: 0.95
# Validation - Cost: 1.16     Accuracy: 0.603
# Epoch 22, CIFAR-10 Batch 3:
# Training -   Cost: 0.525    Accuracy: 0.875
# Validation - Cost: 1.14     Accuracy: 0.604
# Epoch 22, CIFAR-10 Batch 4:
# Training -   Cost: 0.525    Accuracy: 0.875
# Validation - Cost: 1.11     Accuracy: 0.618
# Epoch 22, CIFAR-10 Batch 5:
# Training -   Cost: 0.503    Accuracy: 0.875
# Validation - Cost: 1.11     Accuracy: 0.611
# Epoch 23, CIFAR-10 Batch 1:
# Training -   Cost: 0.631    Accuracy: 0.8
# Validation - Cost: 1.11     Accuracy: 0.612
# Epoch 23, CIFAR-10 Batch 2:
# Training -   Cost: 0.412    Accuracy: 0.9
# Validation - Cost: 1.16     Accuracy: 0.598
# Epoch 23, CIFAR-10 Batch 3:
# Training -   Cost: 0.487    Accuracy: 0.925
# Validation - Cost: 1.12     Accuracy: 0.617
# Epoch 23, CIFAR-10 Batch 4:
# Training -   Cost: 0.481    Accuracy: 0.875
# Validation - Cost: 1.11     Accuracy: 0.617
# Epoch 23, CIFAR-10 Batch 5:
# Training -   Cost: 0.459    Accuracy: 0.9
# Validation - Cost: 1.12     Accuracy: 0.617
# Epoch 24, CIFAR-10 Batch 1:
# Training -   Cost: 0.626    Accuracy: 0.8
# Validation - Cost: 1.11     Accuracy: 0.62
# Epoch 24, CIFAR-10 Batch 2:
# Training -   Cost: 0.409    Accuracy: 0.95
# Validation - Cost: 1.13     Accuracy: 0.611
# Epoch 24, CIFAR-10 Batch 3:
# Training -   Cost: 0.473    Accuracy: 0.925
# Validation - Cost: 1.11     Accuracy: 0.615
# Epoch 24, CIFAR-10 Batch 4:
# Training -   Cost: 0.47     Accuracy: 0.9
# Validation - Cost: 1.11     Accuracy: 0.621
# Epoch 24, CIFAR-10 Batch 5:
# Training -   Cost: 0.436    Accuracy: 0.95
# Validation - Cost: 1.11     Accuracy: 0.617
# Epoch 25, CIFAR-10 Batch 1:
# Training -   Cost: 0.642    Accuracy: 0.775
# Validation - Cost: 1.11     Accuracy: 0.619
# Epoch 25, CIFAR-10 Batch 2:
# Training -   Cost: 0.361    Accuracy: 0.95
# Validation - Cost: 1.14     Accuracy: 0.608
# Epoch 25, CIFAR-10 Batch 3:
# Training -   Cost: 0.477    Accuracy: 0.925
# Validation - Cost: 1.11     Accuracy: 0.616
# Epoch 25, CIFAR-10 Batch 4:
# Training -   Cost: 0.44     Accuracy: 0.9
# Validation - Cost: 1.1      Accuracy: 0.619
# Epoch 25, CIFAR-10 Batch 5:
# Training -   Cost: 0.412    Accuracy: 0.95
# Validation - Cost: 1.11     Accuracy: 0.616
# Epoch 26, CIFAR-10 Batch 1:
# Training -   Cost: 0.629    Accuracy: 0.775
# Validation - Cost: 1.1      Accuracy: 0.619
# Epoch 26, CIFAR-10 Batch 2:
# Training -   Cost: 0.366    Accuracy: 0.925
# Validation - Cost: 1.12     Accuracy: 0.612
# Epoch 26, CIFAR-10 Batch 3:
# Training -   Cost: 0.437    Accuracy: 0.95
# Validation - Cost: 1.1      Accuracy: 0.618
# Epoch 26, CIFAR-10 Batch 4:
# Training -   Cost: 0.43     Accuracy: 0.875
# Validation - Cost: 1.11     Accuracy: 0.618
# Epoch 26, CIFAR-10 Batch 5:
# Training -   Cost: 0.404    Accuracy: 0.95
# Validation - Cost: 1.1      Accuracy: 0.62
# Epoch 27, CIFAR-10 Batch 1:
# Training -   Cost: 0.605    Accuracy: 0.8
# Validation - Cost: 1.09     Accuracy: 0.626
# Epoch 27, CIFAR-10 Batch 2:
# Training -   Cost: 0.37     Accuracy: 0.925
# Validation - Cost: 1.13     Accuracy: 0.607
# Epoch 27, CIFAR-10 Batch 3:
# Training -   Cost: 0.429    Accuracy: 0.975
# Validation - Cost: 1.09     Accuracy: 0.625
# Epoch 27, CIFAR-10 Batch 4:
# Training -   Cost: 0.418    Accuracy: 0.85
# Validation - Cost: 1.1      Accuracy: 0.623
# Epoch 27, CIFAR-10 Batch 5:
# Training -   Cost: 0.377    Accuracy: 0.95
# Validation - Cost: 1.09     Accuracy: 0.625
# Epoch 28, CIFAR-10 Batch 1:
# Training -   Cost: 0.593    Accuracy: 0.775
# Validation - Cost: 1.09     Accuracy: 0.619
# Epoch 28, CIFAR-10 Batch 2:
# Training -   Cost: 0.357    Accuracy: 0.95
# Validation - Cost: 1.11     Accuracy: 0.62
# Epoch 28, CIFAR-10 Batch 3:
# Training -   Cost: 0.426    Accuracy: 0.95
# Validation - Cost: 1.1      Accuracy: 0.631
# Epoch 28, CIFAR-10 Batch 4:
# Training -   Cost: 0.394    Accuracy: 0.9
# Validation - Cost: 1.1      Accuracy: 0.621
# Epoch 28, CIFAR-10 Batch 5:
# Training -   Cost: 0.35     Accuracy: 0.95
# Validation - Cost: 1.08     Accuracy: 0.631
# Epoch 29, CIFAR-10 Batch 1:
# Training -   Cost: 0.557    Accuracy: 0.775
# Validation - Cost: 1.08     Accuracy: 0.626
# Epoch 29, CIFAR-10 Batch 2:
# Training -   Cost: 0.336    Accuracy: 0.95
# Validation - Cost: 1.12     Accuracy: 0.619
# Epoch 29, CIFAR-10 Batch 3:
# Training -   Cost: 0.41     Accuracy: 0.95
# Validation - Cost: 1.09     Accuracy: 0.629
# Epoch 29, CIFAR-10 Batch 4:
# Training -   Cost: 0.362    Accuracy: 0.925
# Validation - Cost: 1.09     Accuracy: 0.622
# Epoch 29, CIFAR-10 Batch 5:
# Training -   Cost: 0.341    Accuracy: 0.95
# Validation - Cost: 1.1      Accuracy: 0.621
# Epoch 30, CIFAR-10 Batch 1:
# Training -   Cost: 0.519    Accuracy: 0.775
# Validation - Cost: 1.09     Accuracy: 0.625
# Epoch 30, CIFAR-10 Batch 2:
# Training -   Cost: 0.31     Accuracy: 0.925
# Validation - Cost: 1.09     Accuracy: 0.631
# Epoch 30, CIFAR-10 Batch 3:
# Training -   Cost: 0.38     Accuracy: 0.975
# Validation - Cost: 1.08     Accuracy: 0.633
# Epoch 30, CIFAR-10 Batch 4:
# Training -   Cost: 0.375    Accuracy: 0.925
# Validation - Cost: 1.1      Accuracy: 0.614
# Epoch 30, CIFAR-10 Batch 5:
# Training -   Cost: 0.333    Accuracy: 0.975
# Validation - Cost: 1.08     Accuracy: 0.628
# Epoch 31, CIFAR-10 Batch 1:
# Training -   Cost: 0.511    Accuracy: 0.85
# Validation - Cost: 1.08     Accuracy: 0.625
# Epoch 31, CIFAR-10 Batch 2:
# Training -   Cost: 0.278    Accuracy: 0.95
# Validation - Cost: 1.11     Accuracy: 0.617
# Epoch 31, CIFAR-10 Batch 3:
# Training -   Cost: 0.384    Accuracy: 0.95
# Validation - Cost: 1.09     Accuracy: 0.63
# Epoch 31, CIFAR-10 Batch 4:
# Training -   Cost: 0.359    Accuracy: 0.95
# Validation - Cost: 1.09     Accuracy: 0.624
# Epoch 31, CIFAR-10 Batch 5:
# Training -   Cost: 0.325    Accuracy: 0.95
# Validation - Cost: 1.08     Accuracy: 0.63
# Epoch 32, CIFAR-10 Batch 1:
# Training -   Cost: 0.494    Accuracy: 0.875
# Validation - Cost: 1.08     Accuracy: 0.629
# Epoch 32, CIFAR-10 Batch 2:
# Training -   Cost: 0.264    Accuracy: 0.95
# Validation - Cost: 1.11     Accuracy: 0.622
# Epoch 32, CIFAR-10 Batch 3:
# Training -   Cost: 0.39     Accuracy: 0.95
# Validation - Cost: 1.08     Accuracy: 0.627
# Epoch 32, CIFAR-10 Batch 4:
# Training -   Cost: 0.32     Accuracy: 0.9
# Validation - Cost: 1.09     Accuracy: 0.629
# Epoch 32, CIFAR-10 Batch 5:
# Training -   Cost: 0.301    Accuracy: 0.95
# Validation - Cost: 1.09     Accuracy: 0.632
# Epoch 33, CIFAR-10 Batch 1:
# Training -   Cost: 0.485    Accuracy: 0.8
# Validation - Cost: 1.09     Accuracy: 0.624
# Epoch 33, CIFAR-10 Batch 2:
# Training -   Cost: 0.277    Accuracy: 0.95
# Validation - Cost: 1.1      Accuracy: 0.626
# Epoch 33, CIFAR-10 Batch 3:
# Training -   Cost: 0.351    Accuracy: 0.95
# Validation - Cost: 1.09     Accuracy: 0.629
# Epoch 33, CIFAR-10 Batch 4:
# Training -   Cost: 0.312    Accuracy: 0.925
# Validation - Cost: 1.08     Accuracy: 0.634
# Epoch 33, CIFAR-10 Batch 5:
# Training -   Cost: 0.293    Accuracy: 0.975
# Validation - Cost: 1.08     Accuracy: 0.629
# Epoch 34, CIFAR-10 Batch 1:
# Training -   Cost: 0.492    Accuracy: 0.875
# Validation - Cost: 1.08     Accuracy: 0.626
# Epoch 34, CIFAR-10 Batch 2:
# Training -   Cost: 0.275    Accuracy: 0.95
# Validation - Cost: 1.1      Accuracy: 0.623
# Epoch 34, CIFAR-10 Batch 3:
# Training -   Cost: 0.34     Accuracy: 0.95
# Validation - Cost: 1.09     Accuracy: 0.632
# Epoch 34, CIFAR-10 Batch 4:
# Training -   Cost: 0.291    Accuracy: 0.95
# Validation - Cost: 1.1      Accuracy: 0.622
# Epoch 34, CIFAR-10 Batch 5:
# Training -   Cost: 0.278    Accuracy: 0.975
# Validation - Cost: 1.08     Accuracy: 0.635
# Epoch 35, CIFAR-10 Batch 1:
# Training -   Cost: 0.46     Accuracy: 0.9
# Validation - Cost: 1.09     Accuracy: 0.625
# Epoch 35, CIFAR-10 Batch 2:
# Training -   Cost: 0.236    Accuracy: 0.95
# Validation - Cost: 1.08     Accuracy: 0.635
# Epoch 35, CIFAR-10 Batch 3:
# Training -   Cost: 0.332    Accuracy: 0.95
# Validation - Cost: 1.08     Accuracy: 0.632
# Epoch 35, CIFAR-10 Batch 4:
# Training -   Cost: 0.289    Accuracy: 0.9
# Validation - Cost: 1.08     Accuracy: 0.633
# Epoch 35, CIFAR-10 Batch 5:
# Training -   Cost: 0.257    Accuracy: 0.95
# Validation - Cost: 1.09     Accuracy: 0.632
# Epoch 36, CIFAR-10 Batch 1:
# Training -   Cost: 0.428    Accuracy: 0.9
# Validation - Cost: 1.07     Accuracy: 0.631
# Epoch 36, CIFAR-10 Batch 2:
# Training -   Cost: 0.244    Accuracy: 0.95
# Validation - Cost: 1.09     Accuracy: 0.629
# Epoch 36, CIFAR-10 Batch 3:
# Training -   Cost: 0.304    Accuracy: 0.95
# Validation - Cost: 1.09     Accuracy: 0.634
# Epoch 36, CIFAR-10 Batch 4:
# Training -   Cost: 0.284    Accuracy: 0.975
# Validation - Cost: 1.08     Accuracy: 0.63
# Epoch 36, CIFAR-10 Batch 5:
# Training -   Cost: 0.255    Accuracy: 0.95
# Validation - Cost: 1.08     Accuracy: 0.632
# Epoch 37, CIFAR-10 Batch 1:
# Training -   Cost: 0.438    Accuracy: 0.825
# Validation - Cost: 1.09     Accuracy: 0.636
# Epoch 37, CIFAR-10 Batch 2:
# Training -   Cost: 0.22     Accuracy: 0.95
# Validation - Cost: 1.09     Accuracy: 0.631
# Epoch 37, CIFAR-10 Batch 3:
# Training -   Cost: 0.309    Accuracy: 0.95
# Validation - Cost: 1.09     Accuracy: 0.632
# Epoch 37, CIFAR-10 Batch 4:
# Training -   Cost: 0.253    Accuracy: 0.975
# Validation - Cost: 1.1      Accuracy: 0.628
# Epoch 37, CIFAR-10 Batch 5:
# Training -   Cost: 0.223    Accuracy: 0.975
# Validation - Cost: 1.08     Accuracy: 0.635
# Epoch 38, CIFAR-10 Batch 1:
# Training -   Cost: 0.411    Accuracy: 0.9
# Validation - Cost: 1.09     Accuracy: 0.64
# Epoch 38, CIFAR-10 Batch 2:
# Training -   Cost: 0.223    Accuracy: 0.975
# Validation - Cost: 1.07     Accuracy: 0.638
# Epoch 38, CIFAR-10 Batch 3:
# Training -   Cost: 0.298    Accuracy: 0.925
# Validation - Cost: 1.09     Accuracy: 0.635
# Epoch 38, CIFAR-10 Batch 4:
# Training -   Cost: 0.255    Accuracy: 0.95
# Validation - Cost: 1.1      Accuracy: 0.633
# Epoch 38, CIFAR-10 Batch 5:
# Training -   Cost: 0.236    Accuracy: 0.95
# Validation - Cost: 1.08     Accuracy: 0.637
# Epoch 39, CIFAR-10 Batch 1:
# Training -   Cost: 0.395    Accuracy: 0.925
# Validation - Cost: 1.09     Accuracy: 0.632
# Epoch 39, CIFAR-10 Batch 2:
# Training -   Cost: 0.195    Accuracy: 0.95
# Validation - Cost: 1.08     Accuracy: 0.638
# Epoch 39, CIFAR-10 Batch 3:
# Training -   Cost: 0.29     Accuracy: 0.95
# Validation - Cost: 1.09     Accuracy: 0.636
# Epoch 39, CIFAR-10 Batch 4:
# Training -   Cost: 0.266    Accuracy: 0.95
# Validation - Cost: 1.1      Accuracy: 0.628
# Epoch 39, CIFAR-10 Batch 5:
# Training -   Cost: 0.229    Accuracy: 0.975
# Validation - Cost: 1.13     Accuracy: 0.631
# Epoch 40, CIFAR-10 Batch 1:
# Training -   Cost: 0.381    Accuracy: 0.95
# Validation - Cost: 1.09     Accuracy: 0.63
# Epoch 40, CIFAR-10 Batch 2:
# Training -   Cost: 0.198    Accuracy: 0.95
# Validation - Cost: 1.1      Accuracy: 0.628
# Epoch 40, CIFAR-10 Batch 3:
# Training -   Cost: 0.28     Accuracy: 0.975
# Validation - Cost: 1.09     Accuracy: 0.64
# Epoch 40, CIFAR-10 Batch 4:
# Training -   Cost: 0.258    Accuracy: 1.0
# Validation - Cost: 1.11     Accuracy: 0.629
# Epoch 40, CIFAR-10 Batch 5:
# Training -   Cost: 0.225    Accuracy: 0.975
# Validation - Cost: 1.12     Accuracy: 0.635
# Epoch 41, CIFAR-10 Batch 1:
# Training -   Cost: 0.375    Accuracy: 0.925
# Validation - Cost: 1.1      Accuracy: 0.631
# Epoch 41, CIFAR-10 Batch 2:
# Training -   Cost: 0.185    Accuracy: 0.95
# Validation - Cost: 1.09     Accuracy: 0.631
# Epoch 41, CIFAR-10 Batch 3:
# Training -   Cost: 0.274    Accuracy: 0.925
# Validation - Cost: 1.09     Accuracy: 0.639
# Epoch 41, CIFAR-10 Batch 4:
# Training -   Cost: 0.219    Accuracy: 0.975
# Validation - Cost: 1.09     Accuracy: 0.632
# Epoch 41, CIFAR-10 Batch 5:
# Training -   Cost: 0.21     Accuracy: 0.975
# Validation - Cost: 1.1      Accuracy: 0.638
# Epoch 42, CIFAR-10 Batch 1:
# Training -   Cost: 0.342    Accuracy: 0.95
# Validation - Cost: 1.09     Accuracy: 0.635
# Epoch 42, CIFAR-10 Batch 2:
# Training -   Cost: 0.187    Accuracy: 0.975
# Validation - Cost: 1.1      Accuracy: 0.634
# Epoch 42, CIFAR-10 Batch 3:
# Training -   Cost: 0.269    Accuracy: 0.925
# Validation - Cost: 1.09     Accuracy: 0.638
# Epoch 42, CIFAR-10 Batch 4:
# Training -   Cost: 0.219    Accuracy: 1.0
# Validation - Cost: 1.09     Accuracy: 0.633
# Epoch 42, CIFAR-10 Batch 5:
# Training -   Cost: 0.2      Accuracy: 0.975
# Validation - Cost: 1.11     Accuracy: 0.629
# Epoch 43, CIFAR-10 Batch 1:
# Training -   Cost: 0.347    Accuracy: 0.95
# Validation - Cost: 1.1      Accuracy: 0.634
# Epoch 43, CIFAR-10 Batch 2:
# Training -   Cost: 0.177    Accuracy: 0.95
# Validation - Cost: 1.1      Accuracy: 0.637
# Epoch 43, CIFAR-10 Batch 3:
# Training -   Cost: 0.261    Accuracy: 0.95
# Validation - Cost: 1.11     Accuracy: 0.636
# Epoch 43, CIFAR-10 Batch 4:
# Training -   Cost: 0.218    Accuracy: 1.0
# Validation - Cost: 1.1      Accuracy: 0.638
# Epoch 43, CIFAR-10 Batch 5:
# Training -   Cost: 0.181    Accuracy: 0.975
# Validation - Cost: 1.15     Accuracy: 0.625
# Epoch 44, CIFAR-10 Batch 1:
# Training -   Cost: 0.341    Accuracy: 0.95
# Validation - Cost: 1.1      Accuracy: 0.634
# Epoch 44, CIFAR-10 Batch 2:
# Training -   Cost: 0.182    Accuracy: 0.95
# Validation - Cost: 1.09     Accuracy: 0.629
# Epoch 44, CIFAR-10 Batch 3:
# Training -   Cost: 0.275    Accuracy: 0.95
# Validation - Cost: 1.1      Accuracy: 0.633
# Epoch 44, CIFAR-10 Batch 4:
# Training -   Cost: 0.217    Accuracy: 1.0
# Validation - Cost: 1.1      Accuracy: 0.63
# Epoch 44, CIFAR-10 Batch 5:
# Training -   Cost: 0.177    Accuracy: 0.975
# Validation - Cost: 1.11     Accuracy: 0.631
# Epoch 45, CIFAR-10 Batch 1:
# Training -   Cost: 0.347    Accuracy: 0.95
# Validation - Cost: 1.13     Accuracy: 0.625
# Epoch 45, CIFAR-10 Batch 2:
# Training -   Cost: 0.172    Accuracy: 0.975
# Validation - Cost: 1.1      Accuracy: 0.629
# Epoch 45, CIFAR-10 Batch 3:
# Training -   Cost: 0.242    Accuracy: 0.95
# Validation - Cost: 1.11     Accuracy: 0.631
# Epoch 45, CIFAR-10 Batch 4:
# Training -   Cost: 0.217    Accuracy: 1.0
# Validation - Cost: 1.1      Accuracy: 0.628
# Epoch 45, CIFAR-10 Batch 5:
# Training -   Cost: 0.182    Accuracy: 0.975
# Validation - Cost: 1.13     Accuracy: 0.635
# Epoch 46, CIFAR-10 Batch 1:
# Training -   Cost: 0.312    Accuracy: 0.95
# Validation - Cost: 1.1      Accuracy: 0.633
# Epoch 46, CIFAR-10 Batch 2:
# Training -   Cost: 0.163    Accuracy: 0.95
# Validation - Cost: 1.1      Accuracy: 0.639
# Epoch 46, CIFAR-10 Batch 3:
# Training -   Cost: 0.231    Accuracy: 0.925
# Validation - Cost: 1.09     Accuracy: 0.636
# Epoch 46, CIFAR-10 Batch 4:
# Training -   Cost: 0.213    Accuracy: 1.0
# Validation - Cost: 1.1      Accuracy: 0.63
# Epoch 46, CIFAR-10 Batch 5:
# Training -   Cost: 0.167    Accuracy: 1.0
# Validation - Cost: 1.11     Accuracy: 0.636
# Epoch 47, CIFAR-10 Batch 1:
# Training -   Cost: 0.325    Accuracy: 0.9
# Validation - Cost: 1.11     Accuracy: 0.632
# Epoch 47, CIFAR-10 Batch 2:
# Training -   Cost: 0.156    Accuracy: 0.975
# Validation - Cost: 1.11     Accuracy: 0.629
# Epoch 47, CIFAR-10 Batch 3:
# Training -   Cost: 0.22     Accuracy: 0.95
# Validation - Cost: 1.11     Accuracy: 0.639
# Epoch 47, CIFAR-10 Batch 4:
# Training -   Cost: 0.191    Accuracy: 1.0
# Validation - Cost: 1.09     Accuracy: 0.632
# Epoch 47, CIFAR-10 Batch 5:
# Training -   Cost: 0.168    Accuracy: 1.0
# Validation - Cost: 1.1      Accuracy: 0.635
# Epoch 48, CIFAR-10 Batch 1:
# Training -   Cost: 0.279    Accuracy: 0.975
# Validation - Cost: 1.11     Accuracy: 0.639
# Epoch 48, CIFAR-10 Batch 2:
# Training -   Cost: 0.158    Accuracy: 0.95
# Validation - Cost: 1.11     Accuracy: 0.626
# Epoch 48, CIFAR-10 Batch 3:
# Training -   Cost: 0.228    Accuracy: 0.95
# Validation - Cost: 1.11     Accuracy: 0.637
# Epoch 48, CIFAR-10 Batch 4:
# Training -   Cost: 0.2      Accuracy: 1.0
# Validation - Cost: 1.1      Accuracy: 0.629
# Epoch 48, CIFAR-10 Batch 5:
# Training -   Cost: 0.168    Accuracy: 0.975
# Validation - Cost: 1.12     Accuracy: 0.636
# Epoch 49, CIFAR-10 Batch 1:
# Training -   Cost: 0.275    Accuracy: 0.975
# Validation - Cost: 1.11     Accuracy: 0.637
# Epoch 49, CIFAR-10 Batch 2:
# Training -   Cost: 0.153    Accuracy: 0.975
# Validation - Cost: 1.1      Accuracy: 0.633
# Epoch 49, CIFAR-10 Batch 3:
# Training -   Cost: 0.218    Accuracy: 0.95
# Validation - Cost: 1.11     Accuracy: 0.639
# Epoch 49, CIFAR-10 Batch 4:
# Training -   Cost: 0.181    Accuracy: 1.0
# Validation - Cost: 1.11     Accuracy: 0.632
# Epoch 49, CIFAR-10 Batch 5:
# Training -   Cost: 0.146    Accuracy: 1.0
# Validation - Cost: 1.12     Accuracy: 0.633
# Epoch 50, CIFAR-10 Batch 1:
# Training -   Cost: 0.285    Accuracy: 1.0
# Validation - Cost: 1.11     Accuracy: 0.636
# Epoch 50, CIFAR-10 Batch 2:
# Training -   Cost: 0.177    Accuracy: 0.95
# Validation - Cost: 1.11     Accuracy: 0.626
# Epoch 50, CIFAR-10 Batch 3:
# Training -   Cost: 0.222    Accuracy: 0.95
# Validation - Cost: 1.12     Accuracy: 0.635
# Epoch 50, CIFAR-10 Batch 4:
# Training -   Cost: 0.189    Accuracy: 1.0
# Validation - Cost: 1.11     Accuracy: 0.627
# Epoch 50, CIFAR-10 Batch 5:
# Training -   Cost: 0.143    Accuracy: 1.0
# Validation - Cost: 1.12     Accuracy: 0.633

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6318359375

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
